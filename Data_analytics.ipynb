# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv("/content/drive/MyDrive/Placement/i1.csv")
df2=pd.read_csv("/content/drive/MyDrive/Placement/i2.csv")

# %%
data=df1.merge(df2,how='outer')
print(data)
# Out:
#              Date            Timestamp  Invoice No.  \
# 0      2023-04-01  2023-04-01 13:16:03        23465
# 1      2023-04-01  2023-04-01 13:16:03        23465
# 2      2023-04-01  2023-04-01 13:16:03        23465
# 3      2023-04-01  2023-04-01 13:16:03        23465
# 4      2023-04-01  2023-04-01 13:16:03        23465
# ...           ...                  ...          ...
# 15616  2023-09-19  2023-09-19 22:03:44        28389
# 15617  2023-09-19  2023-09-19 22:03:44        28389
# 15618  2023-09-19  2023-09-19 22:03:44        28389
# 15619  2023-09-19  2023-09-19 22:03:44        28389
# 15620  2023-09-19  2023-09-19 22:03:44        28389
#
#                          Item Name  Price  Qty.  Sub Total  Discount    Tax  \
# 0              Babycorn Manchurian  160.0   1.0      160.0       0.0   8.00
# 1                Chicken Kati Roll  120.0   1.0      120.0       0.0   6.00
# 2             Paneer Butter Masala  150.0   2.0      300.0       0.0  15.00
# ...

# %%
data.isnull().sum()
# Out:
# Date               0
# Timestamp          0
# Invoice No.        0
# Item Name          0
# Price              0
# Qty.               0
# Sub Total          0
# Discount           0
# Tax                0
# Final Total        0
# Table No.          8
# Server Name        0
# Covers             0
# Variation      15606
# Category           0
# HSN            15621
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15621 entries, 0 to 15620
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         15621 non-null  object
#  1   Timestamp    15621 non-null  object
#  2   Invoice No.  15621 non-null  int64
#  3   Item Name    15621 non-null  object
#  4   Price        15621 non-null  float64
#  5   Qty.         15621 non-null  float64
#  6   Sub Total    15621 non-null  float64
#  7   Discount     15621 non-null  float64
#  8   Tax          15621 non-null  float64
#  9   Final Total  15621 non-null  float64
#  10  Table No.    15613 non-null  float64
#  11  Server Name  15621 non-null  object
#  12  Covers       15621 non-null  int64
#  13  Variation    15 non-null     object
#  14  Category     15621 non-null  object
#  15  HSN          0 non-null      float64
# dtypes: float64(8), int64(2), object(6)
# memory usage: 1.9+ MB

# %%
data.describe()
# Out:
#         Invoice No.         Price          Qty.     Sub Total      Discount  \
# count  15621.000000  15621.000000  15621.000000  15621.000000  15621.000000
# mean   25989.963127    116.608988      1.338839    147.407080      1.262818
# std     1433.192998     63.663769      0.949814    210.127442      6.656396
# min    23465.000000     12.000000      1.000000     12.000000      0.000000
# 25%    24751.000000     50.000000      1.000000     80.000000      0.000000
# 50%    25980.000000    140.000000      1.000000    150.000000      0.000000
# 75%    27274.000000    160.000000      1.000000    170.000000      0.000000
# max    28389.000000    770.000000     28.000000  21560.000000    288.000000
#
#                 Tax   Final Total     Table No.   Covers  HSN
# count  15621.000000  15621.000000  15613.000000  15621.0  0.0
# mean       7.303668    153.447930     18.068340      0.0  NaN
# std       10.461474    219.678163     17.191377      0.0  NaN
# ...

# %%
data.shape
# Out:
# (15621, 16)

# %%
data.drop(['Table No.','Discount','Covers','Variation','Server Name','HSN'],axis=1)
# Out:
#              Date            Timestamp  Invoice No.  \
# 0      2023-04-01  2023-04-01 13:16:03        23465
# 1      2023-04-01  2023-04-01 13:16:03        23465
# 2      2023-04-01  2023-04-01 13:16:03        23465
# 3      2023-04-01  2023-04-01 13:16:03        23465
# 4      2023-04-01  2023-04-01 13:16:03        23465
# ...           ...                  ...          ...
# 15616  2023-09-19  2023-09-19 22:03:44        28389
# 15617  2023-09-19  2023-09-19 22:03:44        28389
# 15618  2023-09-19  2023-09-19 22:03:44        28389
# 15619  2023-09-19  2023-09-19 22:03:44        28389
# 15620  2023-09-19  2023-09-19 22:03:44        28389
#
#                          Item Name  Price  Qty.  Sub Total    Tax  \
# 0              Babycorn Manchurian  160.0   1.0      160.0   8.00
# 1                Chicken Kati Roll  120.0   1.0      120.0   6.00
# 2             Paneer Butter Masala  150.0   2.0      300.0  15.00
# 3                     Pulka (2 No)   40.0   3.0      120.0   6.00
# ...

# %% [markdown]
# Average order value/average purchase value

# %%
total=data['Final Total'].sum()
print(total)
# Out:
# 2397010.12

# %%
uniques=data['Invoice No.'].nunique()
print(uniques)
# Out:
# 4925

# %%
average=total/uniques
print(average)
# Out:
# 486.70256243654825

# %%
grouping=data.groupby("Item Name")['Qty.'].sum()
print(grouping)
# Out:
# Item Name
# 1 Indian Combo - Welcome Drink, Chicken Dum Biriyani, Onion Raita, Chicken Gravy, Boiled Egg, Chicke    29.0
# Aalu Gobi Masala                                                                                         3.0
# Aalu Mutter Masala                                                                                       1.0
# American Chopsey( Veg)                                                                                   1.0
# Baby Corn 65                                                                                            55.0
#                                                                                                         ...
# Vegetable Pepper Soup                                                                                   50.0
# Venila Milk Shake                                                                                       28.0
# ...

# %%
order=grouping.sort_values(ascending=False)
print(order)
# Out:
# Item Name
# Mineral Water                             1672.0
# Chicken Biriyani With Raitha And Gravy    1453.0
# Butter Naan                               1046.0
# Romali Roti (1 No)                         822.0
# Lemon Soda                                 722.0
#                                            ...
# Chicken Malai Kebab                          1.0
# Soft Drinks Tin                              1.0
# Veg Pulav                                    1.0
# American Chopsey( Veg)                       1.0
# Aalu Mutter Masala                           1.0
# Name: Qty., Length: 270, dtype: float64

# %%
top_5=order[0:5]
print(top_5)
# Out:
# Item Name
# Mineral Water                             1672.0
# Chicken Biriyani With Raitha And Gravy    1453.0
# Butter Naan                               1046.0
# Romali Roti (1 No)                         822.0
# Lemon Soda                                 722.0
# Name: Qty., dtype: float64

# %%
sns.barplot(top_5)
# Out:
# <Axes: xlabel='Item Name', ylabel='Qty.'>

# %%
top_5.plot(kind='bar')
# Out:
# <Axes: xlabel='Item Name'>

# %%
grouping=data.groupby("Item Name")['Final Total'].sum()
print(grouping)
# Out:
# Item Name
# 1 Indian Combo - Welcome Drink, Chicken Dum Biriyani, Onion Raita, Chicken Gravy, Boiled Egg, Chicke    6059.54
# Aalu Gobi Masala                                                                                         472.50
# Aalu Mutter Masala                                                                                       157.50
# American Chopsey( Veg)                                                                                   189.00
# Baby Corn 65                                                                                            9124.08
#                                                                                                          ...
# Vegetable Pepper Soup                                                                                   4152.12
# Venila Milk Shake                                                                                       3234.00
# ...

# %%
order=grouping.sort_values(ascending=False)
print(order)
# Out:
# Item Name
# Chicken Biriyani With Raitha And Gravy    240730.96
# Chicken Fried Rice                        119347.20
# Butter Naan                                65387.74
# Thandoor Chicken Half                      53185.83
# Paneer Butter Masala                       49581.22
#                                             ...
# Tomato Soup                                   84.00
# Veg Kothu Parata                              73.50
# Water Bottle 500 Ml                           63.00
# Vechhu Paratha (1 No)                         52.50
# Soft Drinks Tin                               42.00
# Name: Final Total, Length: 270, dtype: float64

# %%
top_10=order[0:5]
print(top_10)
# Out:
# Item Name
# Chicken Biriyani With Raitha And Gravy    240730.96
# Chicken Fried Rice                        119347.20
# Butter Naan                                65387.74
# Thandoor Chicken Half                      53185.83
# Paneer Butter Masala                       49581.22
# Name: Final Total, dtype: float64

# %%
top_10.plot(kind='bar')
# Out:
# <Axes: xlabel='Item Name'>

# %%
grouping=data.groupby("Date")['Final Total'].sum().loc["2023-09-15"]
print(grouping)
# Out:
# 21042.02

# %%
data[data['Date']=='2023-09-15']['Final Total'].sum()
# Out:
# np.float64(21042.02)

# %%
data[(data['Date']=='2023-09-15')&(data["Item Name"]=="Chicken Noodles")]['Qty.'].sum()
# Out:
# np.float64(7.0)

# %%
final=data[data['Final Total']>=2000].get('Invoice No.')
print(final)
# Out:
# 1039     23827
# 4694     24987
# 6103     25427
# 6117     25434
# 11405    27210
# 14772    28126
# Name: Invoice No., dtype: int64

# %%
grouping=data.groupby("Invoice No.")['Final Total'].sum()
grouping[grouping>2000]
# Out:
# Invoice No.
# 23499     2533.64
# 23508     2011.00
# 23637     5644.82
# 23718     3517.50
# 23827    22638.00
#            ...
# 28014     3013.68
# 28126     2887.50
# 28145     4078.68
# 28259     4291.36
# 28315     2004.44
# Name: Final Total, Length: 162, dtype: float64

# %%
grouping=data.groupby("Invoice No.")['Final Total'].sum()
grouping[grouping==2887.50]
# Out:
# Invoice No.
# 28126    2887.5
# Name: Final Total, dtype: float64

# %%
grouping=data.groupby("Invoice No.")['Final Total'].sum().loc[28145]
print(grouping)
# Out:
# 4078.68

# %%
grouping=data.groupby("Invoice No.")['Item Name'].sum().loc[28145]
print(grouping)
# Out:
# Butter Chicken GravyButter Chicken GravyButter NaanChicken Biriyani With Raitha And GravyChicken Chettinad GravyChicken Pallipalayam GravyFish 65Garlic NaanGobi- 65Kadai PaneerKozhi MilaghuperattalMineral WaterPepper Tandoori Chicken ( Full )Pepper Tandoori Chicken ( Half )Romali Roti (1 No)Schewan  Chicken Fried RiceSchewan Chicken NoodleSchezwan Veg Noodles

# %%
grouping=data.groupby("Invoice No.")['Qty.'].sum().loc[28145]
print(grouping)
# Out:
# 40.0

# %%
invoice_no=data[data["Invoice No."]==28145]
result=invoice_no[["Item Name","Qty.","Final Total"]].sum()
print(result)
# Out:
# Item Name      Butter Chicken GravyButter Chicken GravyButter...
# Qty.                                                        40.0
# Final Total                                              4078.68
# dtype: object

# %%
from wordcloud import WordCloud
text=' '.join(data['Item Name'].dropna().astype(str).values)
wordcloud=WordCloud(background_color="white",width=800,height=400).generate(text)
fig, ax=plt.subplots(figsize=(10,6))
ax.imshow(wordcloud,interpolation="bilinear")
ax.set_title("Word cloud")
plt.show()

# %%
from wordcloud import WordCloud
text=' '.join(data['Item Name'].dropna().astype(str).values)
wordcloud=WordCloud(background_color="white",width=800,height=400).generate(text)
fig, ax=plt.subplots(figsize=(10,6))
ax.imshow(wordcloud,interpolation="bicubic")
ax.set_title("Word cloud")
plt.show()

# %%
from wordcloud import WordCloud
text=' '.join(data['Item Name'].dropna().astype(str).values)
wordcloud=WordCloud(background_color="white",width=800,height=400).generate(text)
fig, ax=plt.subplots(figsize=(10,6))
ax.imshow(wordcloud,interpolation="nearest")
ax.set_title("Word cloud")
plt.show()

# %%
from wordcloud import WordCloud
text=' '.join(data['Item Name'].dropna().astype(str).values)
wordcloud=WordCloud(background_color="white",width=800,height=400).generate(text)
fig, ax=plt.subplots(figsize=(10,6))
ax.imshow(wordcloud,interpolation="antialiased")
ax.set_title("Word cloud")
plt.show()

# %%
from wordcloud import WordCloud
text=' '.join(data['Item Name'].dropna().astype(str).values)
wordcloud=WordCloud(background_color="white",width=800,height=400).generate(text)
fig, ax=plt.subplots(figsize=(10,6))
ax.imshow(wordcloud,interpolation="spline36")
ax.set_title("Word cloud")
plt.show()
